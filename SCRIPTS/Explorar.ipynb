# %% [markdown]
# # Exploración y limpieza del dataset
# ### Librerías

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Acceso a los datos

# %%
ruta_catalogo = '../RAW_DATA/catalogo_productos.csv'
ruta_ventas = '../RAW_DATA/ventas_ficticias_santiago_202612.csv'
ruta_detalle = '../RAW_DATA/detalle_pedidos_santiago_202612.xlsx'

df_catalogo = pd.read_csv(ruta_catalogo,
                          dtype={'SKU': object,
                                 "Descripción SKU": object,
                                 "Tipo_embalaje": object})
df_ventas = pd.read_csv(ruta_ventas,
                        dtype={'RUT': object,
                               "Nombre cliente": object,
                               "Número de Orden": object},
                        parse_dates=['Fecha de Pedido',
                                     'Fecha de despacho Solicitada'])

df_detalle = pd.read_excel(ruta_detalle)

# %% [markdown]
# ### Ver Tablas

# %%
display(df_catalogo.head())
# Out:
#          SKU               Descripción SKU  Largo_cm  Ancho_cm  Alto_cm  \
# 0  SKU-00001           Martillo carpintero      33.4      11.5      4.1
# 1  SKU-00002  Escalera aluminio 4 peldaños     118.8      44.3     14.5
# 2  SKU-00003               Cinta aisladora      10.1       9.8      1.9
# 3  SKU-00004             Silicona cartucho      22.8       4.9      5.1
# 4  SKU-00005                  Lámpara mesa      36.5      24.7     24.7
#
#    Volumen_unitario_m3  Peso_unitario_kg           Tipo_embalaje
# 0             0.001575             1.006                A granel
# 1             0.076311             7.662  Embalaje personalizado
# 2             0.000188             0.131                A granel
# 3             0.000570             0.290                A granel
# 4             0.022268             2.362             Caja propia

# %%
display(df_ventas.head())
# Out:
#             RUT          Nombre cliente  \
# 0  14.512.240-4  Cliente Nuevo 14512240
# 1  17.313.403-1        Cliente 17313403
# 2   7.941.056-6   Cliente Nuevo 7941056
# 3  18.305.966-9        Cliente 18305966
# 4  20.329.309-9  Cliente Nuevo 20329309
#
#                           Dirección cliente Fecha de Pedido  \
# 0       Avenida Matta 5370, Santiago, Chile      2026-12-01
# 1  Avenida La Florida 7678, Santiago, Chile      2026-12-01
# 2     Avenida Kennedy 5315, Santiago, Chile      2026-12-01
# 3   Calle San Antonio 8832, Santiago, Chile      2026-12-01
# 4      Calle Catedral 6899, Santiago, Chile      2026-12-01
#
#         Número de Orden  Monto Pedido Fecha de despacho Solicitada  \
# 0  ORD-CL-202612-000001        123929                   2026-12-02
# 1  ORD-CL-202612-000002        118942                   2026-12-03
# 2  ORD-CL-202612-000003        115798                   2026-12-04
# 3  ORD-CL-202612-000004        240273                   2026-12-03
# 4  ORD-CL-202612-000005        230875                   2026-12-04
#
#              Comuna
# 0  Estación Central
# 1          Santiago
# 2     Independencia
# 3          Lo Prado
# 4     Independencia

# %%
display(df_detalle.head())
# Out:
#         Número de Orden        SKU      Descripción SKU  Cantidad  Largo_cm  \
# 0  ORD-CL-202612-000001  SKU-00535    Taladro eléctrico        10      37.8
# 1  ORD-CL-202612-000001  SKU-00664      Rodillo pintura         4      28.5
# 2  ORD-CL-202612-000001  SKU-00469  Monitor 24 pulgadas         1      59.1
# 3  ORD-CL-202612-000001  SKU-00583      Sierra circular         2      45.6
# 4  ORD-CL-202612-000001  SKU-00097  Cable eléctrico 10m         3      23.9
#
#    Ancho_cm  Alto_cm  Volumen_unitario_m3  Peso_unitario_kg  Volumen_total_m3  \
# 0      29.0      9.6             0.010524             2.553          0.105240
# 1      24.9      7.8             0.005535             0.398          0.022140
# 2      46.8     15.4             0.042595             5.133          0.042595
# 3      33.6     14.8             0.022676             5.863          0.045352
# 4      25.5      7.9             0.004815             1.208          0.014445
#
#    Peso_total_kg
# 0         25.530
# 1          1.592
# 2          5.133
# 3         11.726
# 4          3.624

# %% [markdown]
# ### Verificar datos
# #### catálogo

# %%
df_catalogo.dtypes
# Out:
# SKU                     object
# Descripción SKU         object
# Largo_cm               float64
# Ancho_cm               float64
# Alto_cm                float64
# Volumen_unitario_m3    float64
# Peso_unitario_kg       float64
# Tipo_embalaje           object
# dtype: object

# %%
catalogo_numeric = df_catalogo.select_dtypes(include=[np.number])
catalogo_numeric.describe()
# Out:
#          Largo_cm    Ancho_cm     Alto_cm  Volumen_unitario_m3  \
# count  900.000000  900.000000  900.000000           900.000000
# mean    37.969556   24.733111   10.761778             0.018568
# std     29.248601   17.222106    7.898006             0.028831
# min      7.600000    4.800000    1.900000             0.000171
# 25%     19.775000   10.100000    5.100000             0.000818
# 50%     26.950000   20.900000    8.100000             0.005290
# 75%     43.225000   33.825000   14.700000             0.022076
# max    125.900000   72.700000   42.000000             0.121356
#
#        Peso_unitario_kg
# count        900.000000
# mean           2.716397
# std            3.232846
# min            0.108000
# 25%            0.453000
# 50%            1.180500
# 75%            3.753250
# max           13.677000

# %%
catalogo_object = df_catalogo.select_dtypes(include=[object])
display(catalogo_object.describe())
print(catalogo_object["Descripción SKU"].unique())
print(catalogo_object["Tipo_embalaje"].unique())
# Out:
#               SKU    Descripción SKU Tipo_embalaje
# count         900                900           900
# unique        900                 36             3
# top     SKU-00001  Alicate universal   Caja propia
# freq            1                 41           541
# ['Martillo carpintero' 'Escalera aluminio 4 peldaños' 'Cinta aisladora'
#  'Silicona cartucho' 'Lámpara mesa' 'Monitor 24 pulgadas'
#  'Caja herramientas plástica' 'Manguera jardín 20m' 'Router WiFi'
#  'Taladro eléctrico' 'Reloj pared' 'Florero cerámica'
#  'Teclado inalámbrico' 'Amoladora angular' 'Llave ajustable 8 pulgadas'
#  'Rodillo pintura' 'Tarugos nylon bolsa 50u' 'Sierra circular'
#  'Cuadro decorativo 60x40' 'Espejo pared 80x60' 'Parlante Bluetooth'
#  'Cámara seguridad' 'Cable eléctrico 10m' 'Clavos caja 1kg' 'Mouse óptico'
#  'Smartphone caja' 'Alicate universal' 'Notebook 15 pulgadas'
#  'Tornillos caja 100u' 'Estantería modular' 'Broca acero 10mm'
#  'Tablet 10 pulgadas' 'Interruptor eléctrico' 'Pintura látex 4L'
#  'Smart TV 43 pulgadas' 'Pintura látex 1L']
# ['A granel' 'Embalaje personalizado' 'Caja propia']

# %% [markdown]
# ### Estandarizar Rut Cliente

# %%
def estandarizar_rut(row):
    rut = row['RUT']
    rut = rut.replace(' ', '').replace('-', '').replace('.', '')
    if len(rut) == 9:
        rut = rut[:2] + "." + rut[2:5] + "." + rut[5:8] + '-' + rut[8]
    elif len(rut) == 8:
        rut = rut[:1] + "." + rut[1:4] + "." + rut[4:7] + '-' + rut[7]
    return rut

df_ventas["RUT"] = df_ventas.apply(estandarizar_rut, axis=1)
display(df_ventas.head())
# Out:
#             RUT          Nombre cliente  \
# 0  14.512.240-4  Cliente Nuevo 14512240
# 1  17.313.403-1        Cliente 17313403
# 2   7.941.056-6   Cliente Nuevo 7941056
# 3  18.305.966-9        Cliente 18305966
# 4  20.329.309-9  Cliente Nuevo 20329309
#
#                                    Dirección cliente Fecha de Pedido  \
# 0  AV. MATTA 5370 DEPTO 994 ESTACIÓN CENTRAL SANT...      2026-12-01
# 1        Av. La Florida 7678, Macul, Santiago, Chile      2026-12-01
# 2  av. kennedy 5315, depto 694, independencia, sa...      2026-12-01
# 3  Calle San Antonio 8832, Lo Prado, Santiago, Chile      2026-12-01
# 4  Calle Catedral 6899 Depto 1132 Independencia S...      2026-12-01
#
#         Número de Orden  Monto Pedido Fecha de despacho Solicitada
# 0  ORD-CL-202612-000001        123929                   2026-12-02
# 1  ORD-CL-202612-000002        118942                   2026-12-03
# 2  ORD-CL-202612-000003        115798                   2026-12-04
# 3  ORD-CL-202612-000004        240273                   2026-12-03
# 4  ORD-CL-202612-000005        230875                   2026-12-04

# %% [markdown]
# ### Estandarizar direcciones

# %%
import re

# Comunas conocidas para removerlas del string
COMUNAS_SANTIAGO = [
    'Estación Central', 'Quinta Normal', 'Pedro Aguirre Cerda',
    'San Miguel', 'Lo Prado', 'Lo Barnechea', 'Lo Espejo',
    'Las Condes', 'La Florida', 'La Reina', 'La Cisterna',
    'La Granja', 'La Pintana', 'El Bosque', 'Cerro Navia',
    'San Bernardo', 'San Joaquín', 'San Ramón',
    'Puente Alto', 'Peñalolén', 'Independencia', 'Providencia',
    'Recoleta', 'Vitacura', 'Macul', 'Maipú', 'Ñuñoa',
    'Huechuraba', 'Conchalí', 'Cerrillos', 'Quilicura', 'Renca',
    'Santiago'
]
COMUNAS_SANTIAGO.sort(key=len, reverse=True)

# Abreviaturas comunes -> forma completa
ABREVIATURAS = {
    r'\bAv\.?\b':       'Avenida',
    r'\bClle\.?\b':     'Calle',
    r'\bPje\.?\b':      'Pasaje',
    r'\bPsje\.?\b':     'Pasaje',
    r'\bGral\.?\b':     'General',
    r'\bSta\.?\b':      'Santa',
    r'\bSto\.?\b':      'Santo',
    r'\bGran\b':        'Gran',
}

def estandarizar_direccion_y_comuna(direccion):
    """
    Estandariza la dirección y extrae la comuna.
    Retorna una tupla (dirección_estandarizada, comuna)
    """
    if pd.isna(direccion):
        return (direccion, None)

    d = str(direccion)
    comuna_encontrada = None

    # Normalizar espacios múltiples y Title Case
    d = re.sub(r'\s+', ' ', d).strip().title()

    # Eliminar info de depto/dpto
    d = re.sub(r',?\s*(?:Depto|Dpto|Departamento)\.?\s*\d+', '', d, flags=re.IGNORECASE)

    # Normalizar "Stgo" -> "Santiago", "Santiago De Chile" -> "Santiago"
    d = re.sub(r'\bStgo\b', 'Santiago', d)
    d = re.sub(r'Santiago\s+De\s+Chile', 'Santiago', d, flags=re.IGNORECASE)

    # Expandir abreviaturas
    for patron, reemplazo in ABREVIATURAS.items():
        d = re.sub(patron, reemplazo, d, flags=re.IGNORECASE)

    # Separar calle+número del resto usando el primer número de calle
    match = re.match(r'^(.+?\s+\d+)\b(.*)', d)

    if match:
        calle_numero = match.group(1).strip()
        resto = match.group(2).strip()

        # Quitar comuna solo del RESTO (no de la calle)
        for comuna in COMUNAS_SANTIAGO:
            patron = r',?\s*' + re.escape(comuna) + r'\s*,?'
            if re.search(patron, resto, flags=re.IGNORECASE):
                comuna_encontrada = comuna
                resto = re.sub(patron, '', resto, flags=re.IGNORECASE).strip()
                break
        resultado = calle_numero
    else:
        resultado = d
        for comuna in COMUNAS_SANTIAGO:
            patron = r',?\s*' + re.escape(comuna) + r'\s*,?'
            if re.search(patron, resultado, flags=re.IGNORECASE):
                comuna_encontrada = comuna
                resultado = re.sub(patron, '', resultado, flags=re.IGNORECASE).strip()
                break

    # Quitar Santiago, Chile y comas residuales
    resultado = re.sub(r',?\s*Santiago\b', '', resultado, flags=re.IGNORECASE)
    resultado = re.sub(r',?\s*Chile\b', '', resultado, flags=re.IGNORECASE)
    resultado = re.sub(r'\s+', ' ', resultado).strip().strip(',').strip()
    resultado = resultado.replace(".", "")

    # Si no se encontró comuna específica, es Santiago por defecto
    if comuna_encontrada is None:
        comuna_encontrada = 'Santiago'

    return (f"{resultado}, Santiago, Chile", comuna_encontrada)

# Aplicar la función y expandir los resultados en dos columnas
df_ventas[['Dirección cliente', 'Comuna']] = df_ventas['Dirección cliente'].apply(
    lambda x: pd.Series(estandarizar_direccion_y_comuna(x))
)
display(df_ventas[['Dirección cliente', 'Comuna']].head(20))
# Out:
#                                  Dirección cliente            Comuna
# 0              Avenida Matta 5370, Santiago, Chile  Estación Central
# 1         Avenida La Florida 7678, Santiago, Chile          Santiago
# 2            Avenida Kennedy 5315, Santiago, Chile     Independencia
# 3          Calle San Antonio 8832, Santiago, Chile          Lo Prado
# 4             Calle Catedral 6899, Santiago, Chile     Independencia
# 5             Calle Catedral 9181, Santiago, Chile       Puente Alto
# 6               Calle Estado 5634, Santiago, Chile  Estación Central
# 7        Avenida Manuel Montt 685, Santiago, Chile          Recoleta
# 8            Avenida Kennedy 7331, Santiago, Chile     Independencia
# 9   Avenida Américo Vespucio 2389, Santiago, Chile     Independencia
# 10         Avenida Pajaritos 5435, Santiago, Chile          Santiago
# 11            Avenida Grecia 5499, Santiago, Chile       Providencia
# 12       Avenida Manuel Montt 401, Santiago, Chile          Vitacura
# 13         Calle San Antonio 9747, Santiago, Chile       Puente Alto
# 14             Calle Morandé 6751, Santiago, Chile  Estación Central
# 15         Avenida Apoquindo 2937, Santiago, Chile         Peñalolén
# 16             Avenida Matta 4672, Santiago, Chile        Las Condes
# 17       Calle Santo Domingo 6604, Santiago, Chile        La Florida
# 18          Avenida Tobalaba 3402, Santiago, Chile          Santiago
# 19      Avenida Manuel Montt 3031, Santiago, Chile          Santiago

# %% [markdown]
# ### Coordenadas de las direcciones

# %%
#Ordenamos para que corra solo en las primeras 100

df_ventas.sort_values(by='Monto Pedido', ascending=False)
# Out:
#                RUT          Nombre cliente  \
# 3203  15.773.820-4  Cliente Nuevo 15773820
# 2896   8.672.977-1         Cliente 8672977
# 1308  10.996.031-8        Cliente 10996031
# 3055  16.029.558-0  Cliente Nuevo 16029558
# 2876  21.836.478-9  Cliente Nuevo 21836478
# ...            ...                     ...
# 3991  17.625.173-4  Cliente Nuevo 17625173
# 2345  12.122.288-8  Cliente Nuevo 12122288
# 3720  19.950.985-0  Cliente Nuevo 19950985
# 1240   6.639.541-7         Cliente 6639541
# 514   22.361.716-4  Cliente Nuevo 22361716
#
#                              Dirección cliente Fecha de Pedido  \
# 3203       Calle Morandé 2118, Santiago, Chile      2026-12-24
# 2896    Calle Amunátegui 9635, Santiago, Chile      2026-12-22
# 1308         Calle Merced 635, Santiago, Chile      2026-12-11
# 3055       Avenida Matta 5475, Santiago, Chile      2026-12-23
# 2876     Calle San Diego 3231, Santiago, Chile      2026-12-22
# ...                                        ...             ...
# 3991      Calle Catedral 9893, Santiago, Chile      2026-12-30
# 2345  Avenida Las Condes 2361, Santiago, Chile      2026-12-18
# 3720    Avenida Tobalaba 8544, Santiago, Chile      2026-12-28
# 1240    Calle Amunátegui 7313, Santiago, Chile      2026-12-10
# 514    Avenida Pajaritos 1316, Santiago, Chile      2026-12-05
#
#            Número de Orden  Monto Pedido Fecha de despacho Solicitada  \
# 3203  ORD-CL-202612-003204        341061                   2026-12-26
# 2896  ORD-CL-202612-002897        339506                   2026-12-24
# 1308  ORD-CL-202612-001309        339258                   2026-12-13
# 3055  ORD-CL-202612-003056        336536                   2026-12-25
# 2876  ORD-CL-202612-002877        336354                   2026-12-24
# ...                    ...           ...                          ...
# 3991  ORD-CL-202612-003992         34070                   2027-01-03
# 2345  ORD-CL-202612-002346         34001                   2026-12-20
# 3720  ORD-CL-202612-003721         33824                   2026-12-31
# 1240  ORD-CL-202612-001241         33108                   2026-12-12
# 514   ORD-CL-202612-000515         32564                   2026-12-07
#
#              Comuna
# 3203     Las Condes
# 2896       Santiago
# 1308    Puente Alto
# 3055     La Florida
# 2876      Peñalolén
# ...             ...
# 3991       Lo Prado
# 2345     La Florida
# 3720  Quinta Normal
# 1240    Puente Alto
# 514   Independencia
#
# [4180 rows x 8 columns]

# %% [markdown]
# ### Guardar los datos
# en la carpeta ../CLEAN_DATA/

# %%
df_catalogo.to_csv('../CLEAN_DATA/catalogo_productos.csv', index=False)
df_ventas.to_csv('../CLEAN_DATA/ventas_direcciones.csv', index=False)
df_detalle.to_csv('../CLEAN_DATA/detalle_ventas.csv', index=False)

# %%
# import pandas as pd
# from geopy.geocoders import Nominatim
# from geopy.extra.rate_limiter import RateLimiter

# # 1. Initialize with a longer timeout
# geolocator = Nominatim(user_agent="my_unique_application_name", timeout=10)

# # 2. Create a RateLimiter wrapper
# # min_delay_seconds=1 ensures you don't get banned/blocked
# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1, return_value_on_exception=None)

# # 3. Apply the geocoder to the column
# # This will create a 'location' object for each row

# df_ventas['location'] = df_ventas['Dirección cliente'].apply(geocode)

# # 4. Extract lat/lon from the location object
# df_ventas['Latitud'] = df_ventas['location'].apply(lambda loc: loc.latitude if loc else None)
# df_ventas['Longitud'] = df_ventas['location'].apply(lambda loc: loc.longitude if loc else None)

# # Drop the temporary location column if you want
# df_ventas = df_ventas.drop(columns=['location'])

# display(df_ventas.head())

# df_ventas.to_csv('../CLEAN_DATA/ventas_direcciones.csv')
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Calle Santo Domingo 8933, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Calle Santo Domingo 8933, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter swallowed an error after 2 retries. Called with (*('Calle Santo Domingo 8933, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Avenida Santa Rosa 2768, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Avenida Santa Rosa 2768, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter swallowed an error after 2 retries. Called with (*('Avenida Santa Rosa 2768, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Avenida Pedro De Valdivia 7852, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Avenida Pedro De Valdivia 7852, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter swallowed an error after 2 retries. Called with (*('Avenida Pedro De Valdivia 7852, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Avenida Tobalaba 4682, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Avenida Tobalaba 4682, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter swallowed an error after 2 retries. Called with (*('Avenida Tobalaba 4682, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (0/2 tries). Called with (*("Avenida Libertador Bernardo O'Higgins 5746, Santiago, Chile",), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (1/2 tries). Called with (*("Avenida Libertador Bernardo O'Higgins 5746, Santiago, Chile",), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter swallowed an error after 2 retries. Called with (*("Avenida Libertador Bernardo O'Higgins 5746, Santiago, Chile",), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Calle Morandé 2222, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Calle Morandé 2222, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter swallowed an error after 2 retries. Called with (*('Calle Morandé 2222, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Avenida Pajaritos 7516, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Avenida Pajaritos 7516, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter swallowed an error after 2 retries. Called with (*('Avenida Pajaritos 7516, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Calle Merced 4786, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Calle Merced 4786, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter swallowed an error after 2 retries. Called with (*('Calle Merced 4786, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Calle Merced 99, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
# ...
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Avenida Las Condes 4612, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# RateLimiter swallowed an error after 2 retries. Called with (*('Avenida Las Condes 4612, Santiago, Chile',), **{}).
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py", line 500, in _request
#     raise AdapterHTTPError(
#     ...<4 lines>...
#     )
# geopy.adapters.AdapterHTTPError: Non-successful status code 429
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py", line 407, in _adapter_error_handler
#     raise exc_cls(
#         str(error), retry_after=get_retry_after(error.headers)
#     ) from error
# geopy.exc.GeocoderRateLimited: Non-successful status code 429
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 15
#      10 geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1, return_value_on_exception=None)
#      12 # 3. Apply the geocoder to the column
#      13 # This will create a 'location' object for each row
# ---> 15 df_ventas['location'] = df_ventas['Dirección cliente'].apply(geocode)
#      17 # 4. Extract lat/lon from the location object
#      18 df_ventas['Latitud'] = df_ventas['location'].apply(lambda loc: loc.latitude if loc else None)
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\pandas\core\series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\pandas\core\apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\pandas\core\apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\pandas\core\base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\pandas\core\arrays\base.py:2744, in ExtensionArray.map(self, mapper, na_action)
#    2724 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2725     """
#    2726     Map values using an input mapping or function.
#    2727
#    (...)   2742         a MultiIndex will be returned.
#    2743     """
# -> 2744     return map_array(self, mapper, na_action=na_action)
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\pandas\core\algorithms.py:1710, in map_array(arr, mapper, na_action)
#    1708 values = arr.astype(object, copy=False)
#    1709 if na_action is None:
# -> 1710     return lib.map_infer(values, mapper)
#    1711 else:
#    1712     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\extra\rate_limiter.py:274, in RateLimiter.__call__(self, *args, **kwargs)
#     272 self._acquire_request_slot()
#     273 try:
# --> 274     res = self.func(*args, **kwargs)
#     275     if inspect.isawaitable(res):
#     276         raise ValueError(
#     277             "An async awaitable has been passed to `RateLimiter`. "
#     278             "Use `AsyncRateLimiter` instead, which supports awaitables."
#     279         )
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#     474         return resp.json()
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\geopy\adapters.py:482, in RequestsAdapter._request(self, url, timeout, headers)
#     480 def _request(self, url, *, timeout, headers):
#     481     try:
# --> 482         resp = self.session.get(url, timeout=timeout, headers=headers)
#     483     except Exception as error:
#     484         message = str(error)
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\urllib3\connection.py:759, in HTTPSConnection.connect(self)
#     757 try:
#     758     sock: socket.socket | ssl.SSLSocket
# --> 759     self.sock = sock = self._new_conn()
#     760     server_hostname: str = self.host
#     761     tls_in_tls = False
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     199 """Establish a socket connection and set nodelay settings on it.
#     200
#     201 :return: New socket connection.
#     202 """
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#     211     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Users\raalv\__Capstone analytics\CapstoneEnv\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      57 except UnicodeError:
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#      62     sock = None
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     974 # We override this function since we want to translate the numeric family
#     975 # and socket type values to enum constants.
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#     979     addrlist.append((_intenum_converter(af, AddressFamily),
#     980                      _intenum_converter(socktype, SocketKind),
#     981                      proto, canonname, sa))
#
# KeyboardInterrupt:

# %%
#Df chico
# df_chico = df_ventas.head(1000)

# df_chico['location'] = df_chico['Dirección cliente'].apply(geocode)

# # 4. Extract lat/lon from the location object
# df_chico['Latitud'] = df_chico['location'].apply(lambda loc: loc.latitude if loc else None)
# df_chico['Longitud'] = df_chico['location'].apply(lambda loc: loc.longitude if loc else None)

# # Drop the temporary location column if you want
# df_chico = df_chico.drop(columns=['location'])

# display(df_chico.head())

# df_chico.to_csv('../CLEAN_DATA/ventas_direcciones.csv')
